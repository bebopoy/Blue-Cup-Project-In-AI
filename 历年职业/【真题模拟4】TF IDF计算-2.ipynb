# %% [markdown]
# # TF IDF计算
# https://www.lanqiao.cn/courses/40981/learning/?id=2813915&compatibility=false
#
# # 原题
# ```python
# from collections import Counter
# import math
# import jieba
#
# def calc_tfidf(words, corpus):
#     #TODO
#
#
#     pass
#
#
# def main():
#     # 读取输入原始文本 corpus
#     with open('input_a.txt', 'r', encoding='UTF-8') as f:
#         corpus = f.readlines()
#     # 进行分词得到新的 corpus
#     corpus = [jieba.lcut(para) for para in corpus]
#     # 打开输出文件
#     with open('output_a.txt', 'w', encoding='UTF-8') as f:
#         # 对每个词进行 TF-IDF 计算
#         for i, words in enumerate(corpus, 1):
#             tfidf = calc_tfidf(words, corpus)
#
#             # 写入到文件中
#             f.write(f"第{i}段文本：\n")
#             top_words = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:2]
#             for j, (word, score) in enumerate(top_words, 1):
#                 if j != len(top_words):
#                     f.write(f"{word} {score:.5f}\n")
#                 else:
#                     f.write(f"{word} {score:.5f}")
#             if i != len(corpus):
#                 f.write("\n")
#
# if __name__ == '__main__':
#     main()
# ```
# ---
# # 手打题目
# ```python
# from collections import Counter
# import math
# import jieba
#
# def calc_tfidf(words, corpus):
#     wordCounter = Counter(words)
#     tfidf = {}
#     total_corpus = len(corpus)
#     for word in set(words) :
#         tf = wordCounter[word] / len(words)
#         count = 0
#         for corpu in corpus:
#             if word in corpu :
#                 count = count + 1
#         idf = math.log(total_corpus / (count + 1))
#
#         tfidf[word] = tf * idf
#     return tfidf
#
# def main():
#     # 读取输入原始文本 corpus
#     with open('input_a.txt', 'r', encoding='UTF-8') as f:
#         corpus = f.readlines()
#     # 进行分词得到新的 corpus
#     corpus = [jieba.lcut(para) for para in corpus]
#     # 打开输出文件
#     with open('output_a.txt', 'w', encoding='UTF-8') as f:
#         # 对每个词进行 TF-IDF 计算
#         for i, words in enumerate(corpus, 1):
#             tfidf = calc_tfidf(words, corpus)
#
#             # 写入到文件中
#             f.write(f"第{i}段文本：\n")
#             top_words = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:2]
#             for j, (word, score) in enumerate(top_words, 1):
#                 if j != len(top_words):
#                     f.write(f"{word} {score:.5f}\n")
#                 else:
#                     f.write(f"{word} {score:.5f}")
#             if i != len(corpus):
#                 f.write("\n")
#
# if __name__ == '__main__':
#     main()
#
# ```
# <mark>ERROR</mark>:
# * 使用了Counter 可以返回列表各个内容的计数
# * 字典.items() 可以将字典变为元组 ()
#
# ---
# # 参考答案
# ```python
# from collections import Counter
# import math
# import jieba
#
# def calc_tfidf(words, corpus):
#     #TODO
#     word_counter = Counter(words)
#     tfidf = {}
#     total_docs = len(corpus)
#
#     for word in set(words):
#         tf = word_counter[word] / len(words)
#         doc_count = 0
#         for doc in corpus:
#             if word in doc:
#                 doc_count += 1
#         idf = math.log(total_docs / (doc_count+1))
#         tfidf[word] = tf * idf
#     return tfidf
#
#
# def main():
#     # 读取输入原始文本 corpus
#     with open('input_a.txt', 'r', encoding='UTF-8') as f:
#         corpus = f.readlines()
#     # 进行分词得到新的 corpus
#     corpus = [jieba.lcut(para) for para in corpus]
#     # 打开输出文件
#     with open('output_a.txt', 'w', encoding='UTF-8') as f:
#         # 对每个词进行 TF-IDF 计算
#         for i, words in enumerate(corpus, 1):
#             tfidf = calc_tfidf(words, corpus)
#
#             # 写入到文件中
#             f.write(f"第{i}段文本：\n")
#             top_words = sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:2]
#             for j, (word, score) in enumerate(top_words, 1):
#                 if j != len(top_words):
#                     f.write(f"{word} {score:.5f}\n")
#                 else:
#                     f.write(f"{word} {score:.5f}")
#             if i != len(corpus):
#                 f.write("\n")
#
# if __name__ == '__main__':
#     main()
# ```
